# %%
print("Import Pandas")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Import Pandas

# %%
print("\n \n1)Generating a box-and-whisker plot using the built-in boxplot function in the pandas package, showing the distribution of the petal ratio for each of the three species. Be sure to add an appropriate title and axis labels\n\n")

url  =  "https://raw.githubusercontent.com/ongbw/UN5550-Fall2018/master/projects/data/iris.csv"
Flower = pd.read_csv(url)
Flower1 = pd.read_csv(url)
pd.concat([Flower, pd.DataFrame(columns = [ 'Petal ratio', 'Sepal ratio'])], sort = False)
Flower['Petal ratio'] = Flower['Petal.Length']/Flower['Petal.Width']
Flower['Sepal ratio'] = Flower['Sepal.Length']/Flower['Sepal.Width']
Group1 = Flower[['Petal ratio','Species']].groupby('Species').describe()
print Group1
Flower.boxplot(column=['Petal ratio'], by='Species', rot=0, grid=True)
plt.title ('Species v/s Petal Ratio', size= 5)


print("Describe how you choose to handle outliers, and other useful features of your plot (e.g. mean, median, quantiles) Be sure to add an appropriate title and axis labels.")
print("\n \nAnswer: \nThe box plot consists of the minimum, 3 quartiles, a median and a maximum. The verticle lines which is passing through the Quartiles and the median also consists of the Minimum and the Maximum. The points which lie out of the minimum and maximum are called the out-liers. Out-liers are basically the extreme points which should not be considered for calculating the median and mean as the values might not be accurate mean or median, since the extreme points could move them to an extreme values.")
# Out:
#
# 1)Generating a box-and-whisker plot using the built-in boxplot function in the pandas package, showing the distribution of the petal ratio for each of the three species. Be sure to add an appropriate title and axis labels
#
#
#            Petal ratio                                                    \
#                  count      mean       std       min       25%       50%
# Species
# setosa            50.0  7.078000  3.123779  2.666667  4.687500  7.000000
# versicolor        50.0  3.242837  0.312456  2.666667  3.016667  3.240385
# virginica         50.0  2.780662  0.407367  2.125000  2.511364  2.666667
#
#
#                  75%   max
# Species
# setosa      7.875000  15.0
# versicolor  3.417582   4.1
# virginica   3.055556   4.0
# Describe how you choose to handle outliers, and other useful features of your plot (e.g. mean, median, quantiles) Be sure to add an appropriate title and axis labels.
#
#
# Answer:
# ...

# %%
print("Describe how you choose to handle outliers, and other useful features of your plot (e.g. mean, median, quantiles.")
# Out:
# Describe how you choose to handle outliers, and other useful features of your plot (e.g. mean, median, quantiles.

# %%
print("2)Create a similar plot and discussion for the sepal ratio, this time, using the boxplot function in the seaborn package\n \n")

Boxplot_SNS = sns.boxplot(x="Species", y="Sepal ratio", data=Flower)
# Out:
# 2)Create a similar plot and discussion for the sepal ratio, this time, using the boxplot function in the seaborn package

# %%
print("3) Summarize what a violin plot is, and generate a violin plot using the seaborn package for the sepal ratio. Discuss the pros and cons of the boxplot versus the violin plot.")

print("\n \nViolin plot shows all the possible peaks when there are multiple peaks. Since all the peaks are shown,the pros of the plot is that the values can be accurate and the mean, the median and the outliers can be identified using a Violin Plot. The cons can be stated as the range is that the projections can have high extremes. The plot could be unstable since the range where there are no values is also considered.")

Boxplot_SNS = sns.violinplot(x="Species", y="Sepal ratio", data=Flower)
# Out:
# 3) Summarize what a violin plot is, and generate a violin plot using the seaborn package for the sepal ratio. Discuss the pros and cons of the boxplot versus the violin plot.
#
#
# Violin plot shows all the possible peaks when there are multiple peaks. Since all the peaks are shown,the pros of the plot is that the values can be accurate and the mean, the median and the outliers can be identified using a Violin Plot. The cons can be stated as the range is that the projections can have high extremes. The plot could be unstable since the range where there are no values is also considered.

# %%
print("4) Using the built-in pandas plotting tools, make a scatter matrix plot for the four original features (petal width, petal length, sepal width and sepal length). Be sure to color each point in the scatter plot according to the species.\n\n")

Scatter_Plot = sns.pairplot(Flower1, hue = 'Species',palette="husl", markers=["o", "s", "D"])
# Out:
# 4) Using the built-in pandas plotting tools, make a scatter matrix plot for the four original features (petal width, petal length, sepal width and sepal length). Be sure to color each point in the scatter plot according to the species.
